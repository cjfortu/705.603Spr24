# %% [markdown]
# # Model Selection Analysis

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import sklearn
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import f1_score, roc_auc_score

import sys
sys.path.append('..')
from data_pipeline import ETL_Pipeline
from dataset import Fraud_Dataset
from metrics import Metrics

# %% [markdown]
# ### Extract, Transform, and Load the Data

# %%
etlpipe = ETL_Pipeline()
fpth = Path('../data/transactions-1.csv')
etlpipe.extract(fpth)
etlpipe.transform()
pdpth = Path('../data/procdata.csv')
etlpipe.load(pdpth)

# %% [markdown]
# ### Split the Data into Training, Validation, and Testing Sets

# %%
# 10% for testing.  The remaining is split into 5 folds for CV.
datsets = Fraud_Dataset(pdpth, (0.72, 0.18, 0.1))
X_test, Y_test = datsets.get_testing_dataset()
X_trains, X_vals, Y_trains, Y_vals = datsets.get_nfoldCV_datasets()

# %% [markdown]
# ### Validate the XGBoost, Random Forest, and Quadratic Discriminant Analysis Classifiers.

# %%
xgbc = XGBClassifier(tree_method='gpu_hist', max_depth=8, objective='binary:logistic')
rfc = RandomForestClassifier(n_jobs=-1, min_samples_leaf=2)
qdac = QuadraticDiscriminantAnalysis()

# %%
def compare_models(xgbc, qdac, rfc):
    for clf, name in zip([xgbc, qdac, rfc], ['XGB', 'QDA', 'RF']):
        F1_trains = []
        F1_vals = []
        ROCAUC_trains = []
        ROCAUC_vals = []
        print('{} classifier performance:'.format(name))
        for i, (X_train, X_val, Y_train, Y_val) in\
                enumerate(zip(X_trains, X_vals, Y_trains, Y_vals)):
            clf.fit(X_train, Y_train)
            Y_pred_train = clf.predict(X_train)
            Y_pred_val = clf.predict(X_val)

            # we will use F1 score as the first performance metric
            F1_train = f1_score(Y_train, Y_pred_train)
            F1_val = f1_score(Y_val, Y_pred_val)

            # ROC AUC score will be the second performance metric
            ROCAUC_train = roc_auc_score(Y_train, Y_pred_train)
            ROCAUC_val = roc_auc_score(Y_val, Y_pred_val)

            print('fold {} complete'.format(i))

            F1_trains.append(F1_train)
            F1_vals.append(F1_val)
            ROCAUC_trains.append(ROCAUC_train)
            ROCAUC_vals.append(ROCAUC_val)

        print('mean F1_score train: {}, val: {}\nmean ROCAUC train: {}, val: {}\n'.\
              format(np.mean(F1_train), np.mean(F1_val),\
                     np.mean(ROCAUC_train), np.mean(ROCAUC_val)))

compare_models(xgbc, qdac, rfc)
# Out:
# XGB classifier performance:
# fold 0 complete
# fold 1 complete
# fold 2 complete
# fold 3 complete
# fold 4 complete
# mean F1_score train: 0.9659722737044999, val: 0.8970588235294118
# mean ROCAUC train: 0.968763063908454, val: 0.9213212675534856
#
# QDA classifier performance:
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# fold 0 complete
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# fold 1 complete
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# fold 2 complete
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# fold 3 complete
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# fold 4 complete
# mean F1_score train: 0.167940943843923, val: 0.17542016806722688
# mean ROCAUC train: 0.5458339329399914, val: 0.5480713874496258
#
# RF classifier performance:
# fold 0 complete
# fold 1 complete
# fold 2 complete
# fold 3 complete
# fold 4 complete
# mean F1_score train: 0.9235993208828523, val: 0.8449511400651466
# mean ROCAUC train: 0.9305561276586339, val: 0.8732905803899678

# %% [markdown]
# **The XGBoost Classifier had the best mean performance across n-fold CV.**

# %%
def tune():
    for depth in range(4, 12):
        F1_trains = []
        F1_vals = []
        ROCAUC_trains = []
        ROCAUC_vals = []
        print('tree depth: {}'.format(depth))
        for i, (X_train, X_val, Y_train, Y_val) in\
                enumerate(zip(X_trains, X_vals, Y_trains, Y_vals)):
            clf = XGBClassifier(tree_method='gpu_hist', max_depth=depth,\
                          objective='binary:logistic')
            clf.fit(X_train, Y_train)
            Y_pred_train = clf.predict(X_train)
            Y_pred_val = clf.predict(X_val)

            # we will use F1 score as the first performance metric
            F1_train = f1_score(Y_train, Y_pred_train)
            F1_val = f1_score(Y_val, Y_pred_val)

            # ROC AUC score will be the second performance metric
            ROCAUC_train = roc_auc_score(Y_train, Y_pred_train)
            ROCAUC_val = roc_auc_score(Y_val, Y_pred_val)

            print('fold {} complete'.format(i))

            F1_trains.append(F1_train)
            F1_vals.append(F1_val)
            ROCAUC_trains.append(ROCAUC_train)
            ROCAUC_vals.append(ROCAUC_val)

        print('mean F1_score train: {}, val: {}\nmean ROCAUC train: {}, val: {}\n'.\
              format(np.mean(F1_train), np.mean(F1_val),\
                     np.mean(ROCAUC_train), np.mean(ROCAUC_val)))

tune()
# Out:
# tree depth: 4
# fold 0 complete
# fold 1 complete
# fold 2 complete
# fold 3 complete
# fold 4 complete
# mean F1_score train: 0.8759237650719565, val: 0.8572313409724374
# mean ROCAUC train: 0.9049902465595503, val: 0.8982252241865988
#
# tree depth: 5
# fold 0 complete
# fold 1 complete
# fold 2 complete
# fold 3 complete
# fold 4 complete
# mean F1_score train: 0.9015799614643545, val: 0.8706390861376967
# mean ROCAUC train: 0.9207852180438796, val: 0.9057335109805924
#
# tree depth: 6
# fold 0 complete
# fold 1 complete
# fold 2 complete
# fold 3 complete
# fold 4 complete
# mean F1_score train: 0.9199542159481113, val: 0.8826952526799388
# mean ROCAUC train: 0.9336832348872095, val: 0.9146644792738365
#
# tree depth: 7
# fold 0 complete
# fold 1 complete
# fold 2 complete
# fold 3 complete
# fold 4 complete
# mean F1_score train: 0.9448286229705353, val: 0.8896361968816875
# mean ROCAUC train: 0.952196961732562, val: 0.9187064752902921
#
# tree depth: 8
# fold 0 complete
# fold 1 complete
# fold 2 complete
# fold 3 complete
# fold 4 complete
# mean F1_score train: 0.96376058220704, val: 0.8935651113144251
# mean ROCAUC train: 0.9668911605744465, val: 0.9215880163208885
#
# tree depth: 9
# fold 0 complete
# fold 1 complete
# fold 2 complete
# fold 3 complete
# fold 4 complete
# mean F1_score train: 0.980064497214893, val: 0.9001218026796589
# mean ROCAUC train: 0.9810730221896597, val: 0.9253421597178854
#
# tree depth: 10
# fold 0 complete
# fold 1 complete
# fold 2 complete
# fold 3 complete
# fold 4 complete
# mean F1_score train: 0.9911465892597967, val: 0.8956495284453909
# mean ROCAUC train: 0.9913649104170366, val: 0.9236014772390964
#
# tree depth: 11
# fold 0 complete
# fold 1 complete
# fold 2 complete
# fold 3 complete
# fold 4 complete
# mean F1_score train: 0.9976199062387306, val: 0.8929329693660903
# mean ROCAUC train: 0.9976255576341919, val: 0.9235864030590564

# %% [markdown]
# **Based on depth tuning, we select a tree depth of 9.**

# %%
X_train, Y_train = datsets.get_noval_training_dataset()
clf = XGBClassifier(tree_method='gpu_hist', max_depth=9,\
                          objective='binary:logistic')
clf.fit(X_train, Y_train)
Y_pred_test = clf.predict(X_test)

metrics = Metrics(Y_test, Y_pred_test)
rpth = Path('../results/report.txt')
metrics.generate_report(rpth)
# Out:
# Model Testing Results:
#
# note:
# sensitivity = recall of label 1
# specificity = recall of label 0
# _____________________________________________________
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    184275
#            1       0.97      0.85      0.91       965
#
#     accuracy                           1.00    185240
#    macro avg       0.98      0.93      0.95    185240
# weighted avg       1.00      1.00      1.00    185240
#
# ROC-AUC score: 0.9268724584441338
# 'f1:0.907\nprecision:0.969 recall1(sensitivity):0.853 recall0(specificity):0.999 rocauc:0.926'
