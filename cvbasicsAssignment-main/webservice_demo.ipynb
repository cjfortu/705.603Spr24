# %%
# !pip install flask

# %%
# !python objectDetectionService.py
# Out:
# starting server...
#  * Serving Flask app 'objectDetectionService'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8786
#  * Running on http://172.17.0.2:8786
# Press CTRL+C to quit
# file:  <FileStorage: 'dogcat.jpeg' ('image/jpeg')>
# 172.17.0.1 - - [03/Mar/2024 23:58:49] "POST /post HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Mar/2024 23:58:55] "GET /predict HTTP/1.1" 200 -
